# %% [markdown]
# # QUESTION 1

# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\HP\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input ")
designation.send_keys('Data Analyst')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title_tags=driver.find_elements(By.XPATH,"//a[@class='title fw500 ellipsis']")
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)

location_tags=driver.find_elements(By.XPATH,"//li[@class='fleft grey-text br2 placeHolderLi location']")
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,"//a[@class='subTitle ellipsis fleft']")
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
experience_tags=driver.find_elements(By.XPATH,"//li[@class='fleft grey-text br2 placeHolderLi experience']")
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'JOB_TITLE':job_title,'JOB_LOCATION':job_location,'COMPANY_NAME':company_name,'EXP_REQ':experience_required})
df
# Out:
#                                    JOB_TITLE  \
# 0                       Project Data Analyst
# 1                               Data Analyst
# 2                   Executive - Data Analyst
# 3                               Data Analyst
# 4                               Data Analyst
# 5  Senior Data Analyst | Neiman Marcus Group
# 6                        Senior Data Analyst
# 7   Customer Master Data Analyst (SAP SD/MM)
# 8                     Senior Data Analyst II
# 9           Senior Analyst - Data Management
#
#                                         JOB_LOCATION  \
# 0                                Bangalore/Bengaluru
# 1                    Temp. WFH - Bangalore/Bengaluru
# 2                                Bangalore/Bengaluru
# 3                                Bangalore/Bengaluru
# 4                                Bangalore/Bengaluru
# 5                                Bangalore/Bengaluru
# 6  Bangalore/Bengaluru, Kolkata, Hyderabad/Secund...
# ...

# %% [markdown]
# # QUESTION 2

# %%
driver=webdriver.Chrome(r"C:\Users\HP\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input ")
designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div[1]/input")
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]

# %%
title_tags=driver.find_elements(By.XPATH,"//a[@class='title fw500 ellipsis']")
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)

location_tags=driver.find_elements(By.XPATH,"//li[@class='fleft grey-text br2 placeHolderLi location']")
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,"//a[@class='subTitle ellipsis fleft']")
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)

# %%
print(len(job_title),len(job_location),len(company_name))
# Out:
# 10 10 10

# %%
df=pd.DataFrame({'JOB_TITLE':job_title,'JOB_LOCATION':job_location,'COMPANY_NAME':company_name})
df
# Out:
#                                           JOB_TITLE  \
# 0                  Analystics & Modeling Specialist
# 1                                    Data Scientist
# 2                                    Data Scientist
# 3  ACN - Applied Intelligence - Data Scientist - 09
# 4                                    Data Scientist
# 5                               Data Scientist - II
# 6                             Senior Data Scientist
# 7                               Lead Data Scientist
# 8                               Lead Data Scientist
# 9                Data Science - Engineering Manager
#
#                                         JOB_LOCATION      COMPANY_NAME
# 0  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...         Accenture
# 1  Bangalore/Bengaluru, New Delhi, Hyderabad/Secu...       Tata Nexarc
# 2                  Bangalore/Bengaluru, Nagpur, Pune     Tech Mahindra
# 3                                Bangalore/Bengaluru         Accenture
# ...

# %% [markdown]
# # QUESTION 3

# %%
driver=webdriver.Chrome(r"C:\Users\HP\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input ")
designation.send_keys('Data Scientist')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
locationfilter=driver.find_element(By.XPATH,'//*[@id="root"]/div[4]/div/div/section[1]/div[2]/div[5]/div[2]/div[2]/label/i')
locationfilter.click()

# %%
salaryfilter=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[6]/div[2]/div[2]/label/i')
salaryfilter.click()

# %%
job_title=[]
job_location=[]
company_name=[] 
experience_required=[]

# %%
title_tags=driver.find_elements(By.XPATH,"//a[@class='title fw500 ellipsis']")
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)

location_tags=driver.find_elements(By.XPATH,"//li[@class='fleft grey-text br2 placeHolderLi location']")
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,"//a[@class='subTitle ellipsis fleft']")
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
experience_tags=driver.find_elements(By.XPATH,"//li[@class='fleft grey-text br2 placeHolderLi experience']")
for i in experience_tags[0:10]:
    experience=i.text
    experience_required.append(experience)

# %%
print(len(job_title),len(job_location),len(company_name), len(experience_required))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'JOB_TITLE':job_title,'JOB_LOCATION':job_location,'COMPANY_NAME':company_name,'EXP_REQ':experience_required})
df
# Out:
#                                            JOB_TITLE  \
# 0  Artificial Intelligence/Computer Vision Engine...
# 1          Data Activation Specialist - Adobe Target
# 2                  Data Scientist - Engine Algorithm
# 3  Opening For Jr. Data Scientist with Tatras Dat...
# 4                              SE/SSE-Data Scientist
# 5                                     Data Scientist
# 6                                     Data Scientist
# 7  URGENT: Data Scientist | Gurugram | 5 Days Wor...
# 8                                     Data Scientist
# 9                                 Jr. Data Scientist
#
#                                         JOB_LOCATION  \
# 0  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...
# 1  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...
# 2  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...
# 3                                        Delhi / NCR
# 4                                        Delhi / NCR
# 5  Dehradun, Hyderabad/Secunderabad, Gurgaon/Guru...
# ...

# %% [markdown]
# # QUESTION 5

# %%
driver=webdriver.Chrome(r"C:\Users\HP\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.flipkart.com/apple-iphone-11-black--64-gb/product-reviews/itme4e5044ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&marketplace=FLIPKART")

# %%
all_review=driver.find_element(By.XPATH,"//div[@class='gUuXy-']")
all_review.click()

# %%
Rating=[]
Review_summary=[]
Full_review=[]

# %%
    
    rating_tags=driver.find_elements(By.XPATH,"//div[@class='_3LWZlK _1BLPMq']")
    for i in rating_tags[0:100]:
        rating=i.text
        Rating.append(rating)

    review_tags=driver.find_elements(By.XPATH,"//p[@class='_2-N8zT']")
    for i in review_tags[0:100]:
        review=i.text
        Review_summary.append(review)
    
    
    fullreview_tags=driver.find_elements(By.XPATH,"//div[@class='t-ZTKy']")
    for i in fullreview_tags[0:100]:
        fullreview=i.text
        Full_review.append(fullreview)

# %%
df=pd.DataFrame({'RATINGS':Rating,'REVIEWS':Review_summary,'FULL REVIEW':Full_review})
df.head(100)
# Out:
#   RATINGS              REVIEWS  \
# 0       5       Simply awesome
# 1       5     Perfect product!
# 2       5  Best in the market!
# 3       4      Value-for-money
# 4       5    Worth every penny
# 5       5   Highly recommended
# 6       5   Highly recommended
# 7       5     Perfect product!
# 8       5        Great product
# 9       4          Pretty good
#
#                                          FULL REVIEW
# 0  Really satisfied with the Product I received.....
# 1  Amazing phone with great cameras and better ba...
# 2  Great iPhone very snappy experience as apple k...
# 3  I'm Really happy with the product\nDelivery wa...
# 4  Previously I was using one plus 3t it was a gr...
# 5  It's my first time to use iOS phone and I am l...
# 6  What a camera .....just awesome ..you can feel...
# 7  Value for money\n5 star rating\nExcellent came...
# 8  Amazing Powerful and Durable Gadget.\n\nI’m am...
# 9  I was using Iphone 6s and also Oneplus 6t. Bot...

# %% [markdown]
# # QUESTION 7

# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\HP\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.amazon.in")

# %%
product=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
product.send_keys("Laptop")

# %%
search=driver.find_element(By.CLASS_NAME,"nav-right")
search.click()

# %%
cpufilter=driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[6]/li[11]/span/a/div/label/i")
cpufilter.click()

# %%
Title=[]
Ratings=[]
Price=[]

# %%
    
    title_tags=driver.find_elements(By.XPATH,"//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']")
    for i in title_tags[0:10]:
        title=i.text
        Title.append(title)

    rating_tags=driver.find_elements(By.XPATH,"//span[@class='a-size-base']")
    for i in rating_tags[0:10]:
        rating=i.text
        Ratings.append(rating)
    
    
    cost_tags=driver.find_elements(By.XPATH,"//span[@class='a-price-whole']")
    for i in cost_tags[0:10]:
        cost=i.text
        Price.append(cost)

# %%
print(len(Title),len(Ratings),len(Price))
# Out:
# 10 10 10

# %%
df=pd.DataFrame({'TITLE TAG':Title,'RATING':Ratings,'COST':Price})
df
# Out:
#                                            TITLE TAG RATING      COST
# 0  HP Victus Gaming Latest 12th Gen Intel Core i7...  (4.3)    81,990
# 1  Lenovo IdeaPad Slim 5 12th Gen Intel Core i7 1...  (4.2)    82,990
# 2  HP Pavilion Plus, 12th Gen Intel Core i7 16GB ...  (4.0)    94,630
# 3  HP Pavilion 14 12th Gen Intel Core i7 16GB SDR...  (4.3)    88,113
# 4  ASUS ZenBook Duo 14 (2021) Dual Screen Laptop,...  (3.8)  1,04,990
# 5  Lenovo ThinkBook 15 Intel 12th Gen Core i7 15....  (3.7)    91,490
# 6  Lenovo Yoga 7 Intel Evo i7 1260P 14"(35.56cm) ...  (4.3)  1,12,000
# 7  ASUS TUF Gaming F15 (2022), 15.6"(39.62 cms) F...  (3.6)  1,00,000
# 8  Dell Inspiron 5320 Laptop, i7-1260P, 16GB LPDD...  (3.3)    91,800
# 9  (Renewed) HP ProBook 430 G3 6th Gen Intel Core...  (4.0)    24,935

# %% [markdown]
# # QUESTION 9

# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\HP\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.jagranjosh.com/")

# %%
clickgk=driver.find_element(By.XPATH,"/html/body/div/div[1]/div/div[1]/div/div[6]/div/div[1]/header/div[3]/ul/li[9]/a")
clickgk.click()

# %%
clickonlist=driver.find_element(By.XPATH,"/html/body/div[1]/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a")
clickonlist.click()

# %%
Name=[]
BornDead=[]
TERM=[]
REMARK=[]

# %%
urls=driver.find_elements(By.XPATH,"/html/body/div[1]/div[2]/div/div[2]/div/div[1]/div/div/div/div[4]/span/div[3]/table/tbody/tr[2]/td[2]/p/strong/a")

for i in urls:
    urls.append(i.get_attribute('href'))
    
    name_tags=driver.find_elements(By.XPATH,"/html/body/div[1]/div[2]/div/div[2]/div/div[1]/div/div/div/div[4]/span/div[2]/table/tbody/tr[2]/td[2]/p")
    for i in name_tags[0:18]:
        name=i.text
        Name.append(name)

    life_tags=driver.find_elements(By.XPATH,"/html/body/div[1]/div[2]/div/div[2]/div/div[1]/div/div/div/div[4]/span/div[2]/table/tbody/tr[2]/td[3]/p")
    for i in life_tags[0:18]:
        life=i.text
        BornDead.append(life)
    
    
    tenure_tags=driver.find_elements(By.XPATH,"/html/body/div[1]/div[2]/div/div[2]/div/div[1]/div/div/div/div[4]/span/div[2]/table/tbody/tr[2]/td[4]/p[1]")
    for i in tenure_tags[0:18]:
        tenure=i.text
        TERM.append(tenure)
    
    remark_tags=driver.find_elements(By.XPATH,"/html/body/div[1]/div[2]/div/div[2]/div/div[1]/div/div/div/div[4]/span/div[2]/table/tbody/tr[2]/td[5]/p")
    for i in remark_tags[0:18]:
        remark=i.text
        REMARK.append(remark)

# %%
print(len(Name),len(BornDead),len(TERM),len(REMARK))
# Out:
# 0 0 0 0

# %%
df=pd.DataFrame({'NAME':Name,'LIFE':BornDead,'TENURE':TERM,'Remark':REMARK})
df
# Out:
# Empty DataFrame
# Columns: [NAME, LIFE, TENURE, Remark]
# Index: []

# %% [markdown]
# # QUESTION 6

# %%
driver=webdriver.Chrome(r"C:\Users\HP\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.flipkart.com/")

# %%
product=driver.find_element(By.CLASS_NAME,"_3704LK")
product.send_keys('sneakers')

# %%
search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
brand_list = []
product_description_list = []
price_with_discount_list = []
discount_list = []


first_page = 1 
last_page = 4 


for page in range(first_page,last_page):
    
    #to get brads
    brands = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brands:
        brand_list.append(i.text)
        
        
    desc = driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in desc:
        product_description_list.append(i.text)    
    
    
    prices = driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in prices:
        price_with_discount_list.append(i.text)
    
    
    discounts = driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
    for i in discounts:
        discount_list.append(i.text)
        
  
    next_page = driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_page.click()
    
    time.sleep(5)

# %%
brand_list = brand_list[0:100]
product_description_list = product_description_list[0:100]
price_with_discount_list = price_with_discount_list[0:100]
discount_list = discount_list[0:100]

# %%
sneakers= pd.DataFrame(list(zip(brand_list, product_description_list, price_with_discount_list, discount_list)),
                              columns =['Brand', 'Description', 'Price_with_Discount', 'Discount'],
                              index=pd.RangeIndex(start=1, stop=(len(brand_list)+1), name='Sr. No.'))

sneakers.style.set_properties(**{'text-align':'left'}).set_table_styles([ dict(selector='th', props=[('text-align', 'left')])])
# Out:
# <style type="text/css">
# #T_36e50 th {
#   text-align: left;
# }
# ...

# %% [markdown]
# # QUESTION 4

# %%
driver=webdriver.Chrome(r"C:\Users\HP\Downloads\chromedriver_win32\chromedriver.exe")

# %%
driver.get("https://www.flipkart.com")

# %%
product=driver.find_element(By.CLASS_NAME,"_3704LK")
product.send_keys('Sunglasses')

# %%
search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
brand_list = []
product_description_list = []
price_with_discount_list = []
discount_list = []

# %%
first_page = 1
last_page = 4 


for page in range(first_page,last_page):
    
    brands = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brands:
        brand_list.append(i.text)
    
    descriptions = driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in descriptions:
        product_description_list.append(i.text)    
    
    prices = driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in prices:
        price_with_discount_list.append(i.text)
    
    discounts = driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
    for i in discounts:
        discount_list.append(i.text)
           
    next_page = driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_page.click()
    
    time.sleep(5)

# %%
brand_list = brand_list[0:100]
product_description_list = product_description_list[0:100]
price_with_discount_list = price_with_discount_list[0:100]
discount_list = discount_list[0:100]

# %%
SUNGLASSES = pd.DataFrame(list(zip(brand_list, product_description_list, price_with_discount_list, discount_list)),
                              columns =['Brand', 'Description', 'Price_with_Discount', 'Discount'],
                              index=pd.RangeIndex(start=1, stop=(len(brand_list)+1), name='Sr. No.'))

SUNGLASSES.style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align', 'left')])])
# Out:
# <style type="text/css">
# #T_3801f th {
#   text-align: left;
# }
# ...
